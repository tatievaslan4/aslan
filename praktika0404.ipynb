-- %% [markdown]
-- # [praktika0404]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [praktika0404]    Script Date: 02.04.2026 19:57:45 ******/
CREATE DATABASE [praktika0404]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'praktika0404', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\praktika0404.mdf' , SIZE = 73728KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'praktika0404_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL16.SQLEXPRESS\MSSQL\DATA\praktika0404_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [praktika0404] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [praktika0404].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [praktika0404] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [praktika0404] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [praktika0404] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [praktika0404] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [praktika0404] SET ARITHABORT OFF 
GO
ALTER DATABASE [praktika0404] SET AUTO_CLOSE ON 
GO
ALTER DATABASE [praktika0404] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [praktika0404] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [praktika0404] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [praktika0404] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [praktika0404] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [praktika0404] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [praktika0404] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [praktika0404] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [praktika0404] SET  ENABLE_BROKER 
GO
ALTER DATABASE [praktika0404] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [praktika0404] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [praktika0404] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [praktika0404] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [praktika0404] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [praktika0404] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [praktika0404] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [praktika0404] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [praktika0404] SET  MULTI_USER 
GO
ALTER DATABASE [praktika0404] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [praktika0404] SET DB_CHAINING OFF 
GO
ALTER DATABASE [praktika0404] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [praktika0404] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [praktika0404] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [praktika0404] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [praktika0404] SET QUERY_STORE = ON
GO
ALTER DATABASE [praktika0404] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Employee]

-- %%
USE [praktika0404]
GO

-- %%
/****** Object:  Table [dbo].[Employee]    Script Date: 02.04.2026 19:57:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Employee](
	[ID_Employee] [int] IDENTITY(1,1) NOT NULL,
	[FIO] [nvarchar](150) NOT NULL,
	[Position] [nvarchar](100) NULL,
	[Department] [nvarchar](100) NULL,
	[Phone] [nvarchar](20) NULL,
	[Email] [nvarchar](100) NULL,
 CONSTRAINT [PK__Employee__D9EE4F36F489A230] PRIMARY KEY CLUSTERED 
(
	[ID_Employee] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Equipment]

-- %%
/****** Object:  Table [dbo].[Equipment]    Script Date: 02.04.2026 19:57:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Equipment](
	[ID_Equipment] [int] IDENTITY(1,1) NOT NULL,
	[InventoryNumber] [nvarchar](50) NULL,
	[Name] [nvarchar](150) NOT NULL,
	[Type] [nvarchar](80) NOT NULL,
	[Manufacturer] [nvarchar](100) NULL,
	[Model] [nvarchar](100) NULL,
	[Supplier] [nvarchar](150) NULL,
	[PurchaseDate] [date] NULL,
	[PurchasePrice] [money] NULL,
	[Status] [nvarchar](50) NOT NULL,
	[Description] [nvarchar](max) NULL,
	[Image] [varbinary](max) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_Equipment] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[InventoryNumber] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EquipmentAssignment]

-- %%
/****** Object:  Table [dbo].[EquipmentAssignment]    Script Date: 02.04.2026 19:57:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EquipmentAssignment](
	[ID_Assignment] [int] IDENTITY(1,1) NOT NULL,
	[EquipmentID] [int] NOT NULL,
	[EmployeeID] [int] NOT NULL,
	[IssueDate] [date] NOT NULL,
	[ReturnDate] [date] NULL,
	[ConditionAtIssue] [nvarchar](100) NULL,
	[Notes] [nvarchar](max) NULL,
 CONSTRAINT [PK__Equipmen__64B923A02BD855AD] PRIMARY KEY CLUSTERED 
(
	[ID_Assignment] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Userr]

-- %%
/****** Object:  Table [dbo].[Userr]    Script Date: 02.04.2026 19:57:45 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Userr](
	[ID_User] [int] IDENTITY(1,1) NOT NULL,
	[Role] [nvarchar](50) NOT NULL,
	[FIO] [nvarchar](150) NOT NULL,
	[Login] [nvarchar](50) NOT NULL,
	[Password] [nvarchar](50) NOT NULL,
PRIMARY KEY CLUSTERED 
(
	[ID_User] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY],
UNIQUE NONCLUSTERED 
(
	[Login] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__Equipment__Statu__3D5E1FD2]

-- %%
ALTER TABLE [dbo].[Equipment] ADD  DEFAULT ('В наличии') FOR [Status]
GO

-- %% [markdown]
-- # [FK_Assignment_Employee]

-- %%
ALTER TABLE [dbo].[EquipmentAssignment]  WITH CHECK ADD  CONSTRAINT [FK_Assignment_Employee] FOREIGN KEY([EmployeeID])
REFERENCES [dbo].[Employee] ([ID_Employee])
GO
ALTER TABLE [dbo].[EquipmentAssignment] CHECK CONSTRAINT [FK_Assignment_Employee]
GO

-- %% [markdown]
-- # [praktika0404]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [praktika0404] SET  READ_WRITE 
GO
